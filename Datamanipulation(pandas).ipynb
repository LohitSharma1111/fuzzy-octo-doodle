# %%
import pandas as pd

# %%
#main datatypes
#1.Series is 1-dimensional
series=pd.Series(["bmw","BENZ","volvo"])

# %%
print(series)
# Out:
# 0      bmw
# 1     BENZ
# 2    volvo
# dtype: object

# %%
colours=pd.Series(["black","red","blue"])
colours
# Out:
# 0    black
# 1      red
# 2     blue
# dtype: object

# %%
#DataFrame is 2-Dimensional 
car=pd.DataFrame({"Model": series, "colour":colours})
car
# Out:
#    Model colour
# 0    bmw  black
# 1   BENZ    red
# 2  volvo   blue

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe data

# %%
#attributes doesnt contains brackets
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car.describe()
# Out:
#        Model colour
# count      3      3
# unique     3      3
# top      bmw  black
# freq       1      1

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean() # gives the mean value of prices
# Out:
# C:\Users\LOHITH~1\AppData\Local\Temp/ipykernel_9188/2905645739.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean() # gives the mean value of prices
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].mean()
# Out:
# 4.0

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc and .iloc referes to LOCATION

# %%
bikes=pd.Series(["bmw","ducati","TRIUMPH"],index= [0 , 5 , 6])
bikes
# Out:
# 0        bmw
# 5     ducati
# 6    TRIUMPH
# dtype: object

# %%
bikes.loc[5]
# Out:
# 'ducati'

# %%
bikes.iloc[2] #iloc refers to the position
# Out:
# 'TRIUMPH'

# %%
bikes
# Out:
# 0        bmw
# 5     ducati
# 6    TRIUMPH
# dtype: object

# %%
bikes.loc[0]
# Out:
# 'bmw'

# %%
bikes.loc[:2]
# Out:
# 0    bmw
# dtype: object

# %%
bikes.loc[:3]
# Out:
# 0    bmw
# dtype: object

# %%
bikes.iloc[:3]
# Out:
# 0        bmw
# 5     ducati
# 6    TRIUMPH
# dtype: object

# %%
bikes.iloc[:2]
# Out:
# 0       bmw
# 5    ducati
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Doors"]
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
#to Get data in mate coloums
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>1000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales["Odometer (KM)"]>=10000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#crosstab way to compare 2 coloumns NO OF ELEMENTS IN 2 cOLOUMNS
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Doors"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Make"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulating data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales #Pandas require reassigning to change the data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"]=car_sales["Make"].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  TOYOTA  White         150043      4   $4,000.00
# 1   HONDA    Red          87899      4   $5,000.00
# 2  TOYOTA   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  NISSAN  White         213095      4   $3,500.00
# 5  TOYOTA  Green          99213      4   $4,500.00
# 6   HONDA   Blue          45698      4   $7,500.00
# 7   HONDA   Blue          54738      4   $7,000.00
# 8  TOYOTA  White          60000      4   $6,250.00
# 9  NISSAN  White          31600      4   $9,700.00

# %% [markdown]
# # Missing data

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  TOYOTA  White         150043      4   $4,000.00
# 1   HONDA    Red          87899      4   $5,000.00
# 2  TOYOTA   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  NISSAN  White         213095      4   $3,500.00
# 5  TOYOTA  Green          99213      4   $4,500.00
# 6   HONDA   Blue          45698      4   $7,500.00
# 7   HONDA   Blue          54738      4   $7,000.00
# 8  TOYOTA  White          60000      4   $6,250.00
# 9  NISSAN  White          31600      4   $9,700.00

# %% [markdown]
# # Create a series or coloumn

# %%
#coloumn from series
seats_coloumn = pd.Series([5,5,5,5,5])
#new coloumn
car_sales["seats"]=seats_coloumn

# %%
car_sales #when we create a series coloums it defaultly adds at right atmost
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  TOYOTA  White         150043      4   $4,000.00    5.0
# 1   HONDA    Red          87899      4   $5,000.00    5.0
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  NISSAN  White         213095      4   $3,500.00    5.0
# 5  TOYOTA  Green          99213      4   $4,500.00    NaN
# 6   HONDA   Blue          45698      4   $7,500.00    NaN
# 7   HONDA   Blue          54738      4   $7,000.00    NaN
# 8  TOYOTA  White          60000      4   $6,250.00    NaN
# 9  NISSAN  White          31600      4   $9,700.00    NaN

# %%
car_sales["seats"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  TOYOTA  White         150043      4   $4,000.00    5.0
# 1   HONDA    Red          87899      4   $5,000.00    5.0
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  NISSAN  White         213095      4   $3,500.00    5.0
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0
# 6   HONDA   Blue          45698      4   $7,500.00    5.0
# 7   HONDA   Blue          54738      4   $7,000.00    5.0
# 8  TOYOTA  White          60000      4   $6,250.00    5.0
# 9  NISSAN  White          31600      4   $9,700.00    5.0

# %%
Engine_coloumn=pd.Series([500,1230,1234,1432])
car_sales["Engine"]=Engine_coloumn

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Engine
# 0  TOYOTA  White         150043      4   $4,000.00    5.0   500.0
# 1   HONDA    Red          87899      4   $5,000.00    5.0  1230.0
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0  1234.0
# 3     BMW  Black          11179      5  $22,000.00    5.0  1432.0
# 4  NISSAN  White         213095      4   $3,500.00    5.0     NaN
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0     NaN
# 6   HONDA   Blue          45698      4   $7,500.00    5.0     NaN
# 7   HONDA   Blue          54738      4   $7,000.00    5.0     NaN
# 8  TOYOTA  White          60000      4   $6,250.00    5.0     NaN
# 9  NISSAN  White          31600      4   $9,700.00    5.0     NaN

# %%
car_sales["Engine"].fillna(1200, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Engine
# 0  TOYOTA  White         150043      4   $4,000.00    5.0   500.0
# 1   HONDA    Red          87899      4   $5,000.00    5.0  1230.0
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0  1234.0
# 3     BMW  Black          11179      5  $22,000.00    5.0  1432.0
# 4  NISSAN  White         213095      4   $3,500.00    5.0  1200.0
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0  1200.0
# 6   HONDA   Blue          45698      4   $7,500.00    5.0  1200.0
# 7   HONDA   Blue          54738      4   $7,000.00    5.0  1200.0
# 8  TOYOTA  White          60000      4   $6,250.00    5.0  1200.0
# 9  NISSAN  White          31600      4   $9,700.00    5.0  1200.0

# %%
#creating coloumn from python list
mileage=[24,32,14,16,17,13,19,31,25,12]
car_sales["Mileage"]=mileage

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Engine  Mileage
# 0  TOYOTA  White         150043      4   $4,000.00    5.0   500.0       24
# 1   HONDA    Red          87899      4   $5,000.00    5.0  1230.0       32
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0  1234.0       14
# 3     BMW  Black          11179      5  $22,000.00    5.0  1432.0       16
# 4  NISSAN  White         213095      4   $3,500.00    5.0  1200.0       17
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0  1200.0       13
# 6   HONDA   Blue          45698      4   $7,500.00    5.0  1200.0       19
# 7   HONDA   Blue          54738      4   $7,000.00    5.0  1200.0       31
# 8  TOYOTA  White          60000      4   $6,250.00    5.0  1200.0       25
# 9  NISSAN  White          31600      4   $9,700.00    5.0  1200.0       12

# %%
car_sales["Petrol"]=car_sales["Odometer (KM)"] / car_sales["Mileage"] #creating new coloumn with other coloumns

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Engine  Mileage  \
# 0  TOYOTA  White         150043      4   $4,000.00    5.0   500.0       24
# 1   HONDA    Red          87899      4   $5,000.00    5.0  1230.0       32
# 2  TOYOTA   Blue          32549      3   $7,000.00    5.0  1234.0       14
# 3     BMW  Black          11179      5  $22,000.00    5.0  1432.0       16
# 4  NISSAN  White         213095      4   $3,500.00    5.0  1200.0       17
# 5  TOYOTA  Green          99213      4   $4,500.00    5.0  1200.0       13
# 6   HONDA   Blue          45698      4   $7,500.00    5.0  1200.0       19
# 7   HONDA   Blue          54738      4   $7,000.00    5.0  1200.0       31
# 8  TOYOTA  White          60000      4   $6,250.00    5.0  1200.0       25
# 9  NISSAN  White          31600      4   $9,700.00    5.0  1200.0       12
#
#          Petrol
# 0   6251.791667
# 1   2746.843750
# 2   2324.928571
# 3    698.687500
# 4  12535.000000
# 5   7631.769231
# 6   2405.157895
# ...

# %%
car_sales
#to remove a coloumn
#coloumns are on axis=1
car_sales=car_sales.drop("seats",axis=1) #some functions require axis

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Engine  Mileage  \
# 0  TOYOTA  White         150043      4   $4,000.00   500.0       24
# 1   HONDA    Red          87899      4   $5,000.00  1230.0       32
# 2  TOYOTA   Blue          32549      3   $7,000.00  1234.0       14
# 3     BMW  Black          11179      5  $22,000.00  1432.0       16
# 4  NISSAN  White         213095      4   $3,500.00  1200.0       17
# 5  TOYOTA  Green          99213      4   $4,500.00  1200.0       13
# 6   HONDA   Blue          45698      4   $7,500.00  1200.0       19
# 7   HONDA   Blue          54738      4   $7,000.00  1200.0       31
# 8  TOYOTA  White          60000      4   $6,250.00  1200.0       25
# 9  NISSAN  White          31600      4   $9,700.00  1200.0       12
#
#          Petrol
# 0   6251.791667
# 1   2746.843750
# 2   2324.928571
# 3    698.687500
# 4  12535.000000
# 5   7631.769231
# 6   2405.157895
# 7   1765.741935
# 8   2400.000000
# 9   2633.333333

# %%
car_sales.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price  Engine  Mileage  \
# 0      0  TOYOTA  White         150043      4   $4,000.00   500.0       24
# 1      1   HONDA    Red          87899      4   $5,000.00  1230.0       32
# 2      2  TOYOTA   Blue          32549      3   $7,000.00  1234.0       14
# 3      3     BMW  Black          11179      5  $22,000.00  1432.0       16
# 4      4  NISSAN  White         213095      4   $3,500.00  1200.0       17
# 5      5  TOYOTA  Green          99213      4   $4,500.00  1200.0       13
# 6      6   HONDA   Blue          45698      4   $7,500.00  1200.0       19
# 7      7   HONDA   Blue          54738      4   $7,000.00  1200.0       31
# 8      8  TOYOTA  White          60000      4   $6,250.00  1200.0       25
# 9      9  NISSAN  White          31600      4   $9,700.00  1200.0       12
#
#          Petrol
# 0   6251.791667
# 1   2746.843750
# 2   2324.928571
# 3    698.687500
# 4  12535.000000
# 5   7631.769231
# 6   2405.157895
# ...

# %%
car_sales=car_sales.reset_index(drop=True,inplace=True)

# %%
print(car_sales)
